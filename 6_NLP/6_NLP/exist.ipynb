# %%
import nltk
import re
from nltk.corpus import gutenberg
from nltk.corpus import brown
from nltk.corpus import state_union
from nltk.corpus import wordnet as wn
from nltk.corpus import swadesh
from nltk.book import text1 as mobydick 
from nltk.book import text2 as sense_and_sensibility 
from nltk import book
from nltk.corpus import names 
from nltk.corpus import cmudict 
from nltk.corpus import stopwords 
from matplotlib import pyplot
import random

# %% [markdown]
# # Đọc kĩ đề bài
# text 1-5 là trong nltk có hết trong nltk.book
#
# code trong này có thể cần chỉnh lại format theo cho đúng với yêu cầu đề (vd mấy câu có __name__ == '__main__:', ...)

# %%
# TODO: xóa tất cả comment sau khi dùng code

# %% [markdown]
# define s as text
# Write expressions for finding all words in s that meet the conditions (contain z, end with ize,...) listed below. The result should be in the form of a list of words: ['word1', 'word2', ...].

# %%
# Ending in ize
print([w for w in s if w.endswith('ize')])
# Containing the letter z
print([w for w in s if 'z' in w])
# Containing the sequence of letters pt
print([w for w in s if 'pt' in w])
# Having all lowercase letters except for an initial capital (i.e., titlecase)
print([w for w in s if w.istitle()])

# %% [markdown]
# Write a program to find all words that occur at least three times in the Brown Corpus.

# %%
all_unique_words_brown=set(brown.words())
brown_fd=nltk.FreqDist(brown.words())
atleast_3times=[word for word in all_unique_words_brown if brown_fd[word]>2]
print(atleast_3times)
# Out:
# ['Platonic', 'permanently', 'Brennan', '$15', 'obsession', 'hug', 'ml', 'bulge', 'agonizing', 'dedication', 'manuscript', 'housewife', 'try', "You've", 'knows', 'folksy', 'brandy', 'refrigerated', 'splitting', 'curbing', '$300', 'compartment', 'slid', 'Oh', 'Bank', '332', 'coincide', 'stemmed', 'lunar', 'involutions', 'proud', 'Memorial', 'obstructed', 'Tory', 'hesitant', 'fired', 'transit', 'Conservation', 'slums', 'Architect', 'Plan', 'interviews', 'artillery', 'thinking', 'bloc', 'floral', 'mysteries', 'vs', 'carelessly', 'menarche', 'Glendora', 'responding', "Moscow's", 'instrumentalities', 'natures', 'Mark', 'Lyndon', 'Sing', 'hover', "Adams'", 'Guatemala', "Washington's", 'pronouncement', 'worthy', 'bristle', 'apprentice', 'Married', 'encountered', 'McCullough', 'backgrounds', 'heavy', 'polynomials', 'plumbing', 'filing', 'Airport', 'lilacs', 'aberrant', 'operations', 'abuse', 'opened', 'national', 'enlightening', 'humorous', 'tappet', 'thirsty', 'decimal', 'Garibaldi', 'chroni
# ...

# %% [markdown]
# Write a Python NLTK program to tokenize words, sentence wise.
# Sample Output:
# Original string:
# Joe waited for the train. The train was late. Mary and Samantha took the bus. I looked for Mary and Samantha at the bus station.
# Tokenize words sentence wise:
# Read the list:
# ['Joe', 'waited', 'for', 'the', 'train', '.']
# ['The', 'train', 'was', 'late', '.']
# ['Mary', 'and', 'Samantha', 'took', 'the', 'bus', '.'
# ['T', 'looked', 'for', 'Mary', 'and', 'Samantha', 'at', 'the', 'bus', 'station', '.']

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
text = "Joe waited for the train. The train was late. Mary and Samantha took the bus. I looked for Mary and Samantha at the bus station."
print("\nOriginal string:")
print(text)
print("\nTokenize words sentence wise:")
result = [word_tokenize(t) for t in sent_tokenize(text)]
print("\nRead the list:")
for s in result:
    print(s)
# Out:
# Original string:
# Joe waited for the train. The train was late. Mary and Samantha took the bus. I looked for Mary and Samantha at the bus station.
#
# Tokenize words sentence wise:
#
# Read the list:
# ['Joe', 'waited', 'for', 'the', 'train', '.']
# ['The', 'train', 'was', 'late', '.']
# ['Mary', 'and', 'Samantha', 'took', 'the', 'bus', '.']
# ['I', 'looked', 'for', 'Mary', 'and', 'Samantha', 'at', 'the', 'bus', 'station', '.']

# %% [markdown]
# Replace the pronouns in below text by the respective object names
# Input:
# text=" My sister has a dog and she loves him"
# Desired Output:
# [My sister,she]
# [a dog,him]

# %%
# trong file code.py

# %% [markdown]
# Write a function that finds the 50 most frequently occurring words of a text that are not stopwords.

# %%
def freq_non_stopwords(text):
	stopwords = nltk.corpus.stopwords.words('english')
	clean_list = [w for w in text if w.lower() not in stopwords]
	freqdist = nltk.probability.FreqDist(clean_list)
	return freqdist.keys()[:50]

# %% [markdown]
# Write a Python NLTK program to split all punctuation into separate tokens.
# Sample Output:
# Original string:
# Reset your password if you just can't remember your old one.
# Split all punctuation into separate tokens:
# ['Reset', 'your', 'password', 'if', 'you', 'just', 'can', """", 't', 'remember', 'your', 'old', 'one', '.']

# %%
from nltk.tokenize import WordPunctTokenizer
text = "Reset your password if you just can't remember your old one."
print("\nOriginal string:")
print(text)
result = WordPunctTokenizer().tokenize(text)
print("\nSplit all punctuation into separate tokens:")
print(result)
# Out:
# Original string:
# Reset your password if you just can't remember your old one.
#
# Split all punctuation into separate tokens:
# ['Reset', 'your', 'password', 'if', 'you', 'just', 'can', "'", 't', 'remember', 'your', 'old', 'one', '.']

# %% [markdown]
# Find the similarity between any two text documents
# Input:
# text1="John lives in Canada"
# text2="James lives in America, though he's not from there"
# Desired Output:
# Similarity between textl and text2 is 0.792817083631068

# %%
# trong file code.py

# %% [markdown]
# Define a function percent(word, text) that calculates how often a given word occurs in a text and expresses the result as a percentage.

# %%
def percent(word, text):
    return nltk.probability.FreqDist(text)[word]/float(len(text))*100
percent("the",book.text1)

# %% [markdown]
# Write a Python NLTK program to split the text sentence/paragraph into a list of words.
# Sample Output:
# Original string:
# Joe waited for the train. The train was late. Mary and Samantha took the bus. I looked for Mary and Samantha at the bus station.
# Sentence-tokenized copy in a list:
# ['Joe waited for the train.', 'The train was late.', 'Mary and Samantha took the bus.', 'I looked for Mary and Samantha at the bus station.]
# Read the list:
# Joe waited for the train.
# The train was late.
# Mary and Samantha took the bus. I looked for Mary and Samantha at the bus station.

# %%
import nltk

from nltk.tokenize import sent_tokenize

def tokenize_text(text):
    # Tokenize the text into sentences
    sentences = sent_tokenize(text)
    return sentences

if __name__ == "__main__":
    # Sample text
    original_text = "Joe waited for the train. The train was late. Mary and Samantha took the bus. I looked for Mary and Samantha at the bus station."

    # Tokenize the text into sentences
    tokenized_sentences = tokenize_text(original_text)

    # Display the original text
    print("Original string:")
    print(original_text)

    # Display the sentence-tokenized copy in a list
    print("\nSentence-tokenized copy in a list:")
    print(tokenized_sentences)

    # Display the sentences read from the list
    print("\nRead the list:")
    for sentence in tokenized_sentences:
        print(sentence)
# Out:
# Original string:
# Joe waited for the train. The train was late. Mary and Samantha took the bus. I looked for Mary and Samantha at the bus station.
#
# Sentence-tokenized copy in a list:
# ['Joe waited for the train.', 'The train was late.', 'Mary and Samantha took the bus.', 'I looked for Mary and Samantha at the bus station.']
#
# Read the list:
# Joe waited for the train.
# The train was late.
# Mary and Samantha took the bus.
# I looked for Mary and Samantha at the bus station.

# %% [markdown]
# Extract the Verb Phrases from the given text
# Input:
# text = ("I may bake a cake for my birthday. The talk will introduce reader about Use of baking")
# Desired Output:
# may bake
# will introduce

# %%
# trong file code.py

# %% [markdown]
# Find all the four-letter words in the Chat Corpus (text5). With the help of a frequency distribution (FreqDist), show these words in decreasing order of frequency

# %%
freqDistText5 = nltk.probability.FreqDist(book.text5)
text5FourLetterWords = sorted(set([w for w in book.text5 if w.isalpha() and len(w) == 4]))
print(text5FourLetterWords)
print(freqDistText5)
for sample in [w for w in freqDistText5]:
    if sample not in text5FourLetterWords:
        freqDistText5.pop(sample)
print(freqDistText5)
freqDistText5.plot(50)

# %% [markdown]
# Write a Python NLTK program to create a list of words from a given string.
# Sample Output:
# Original string:
# Joe waited for the train. The train was late. Mary and Samantha took the bus. I looked for Mary and Samantha at the bus station.
# List of words:
# ['Joe', 'waited', 'for', 'the', 'train', '.'. 'The', 'train', 'was', 'late', '', 'Mary', 'and', 'Samantha, 'took', 'the', 'bus', '', 'T', 'looked', 'for', 'Mary', 'and', 'Samantha', 'at', 'the', 'bus', 'station', '')

# %%
import nltk
from nltk.tokenize import word_tokenize

def tokenize_words(text):
    # Tokenize the text into words
    words = word_tokenize(text)
    return words

if __name__ == "__main__":
    # Sample text
    original_text = "Joe waited for the train. The train was late. Mary and Samantha took the bus. I looked for Mary and Samantha at the bus station."

    # Tokenize the text into words
    tokenized_words = tokenize_words(original_text)

    # Display the original text
    print("Original string:")
    print(original_text)

    # Display the list of words
    print("\nList of words:")
    print(tokenized_words)
# Out:
# Original string:
# Joe waited for the train. The train was late. Mary and Samantha took the bus. I looked for Mary and Samantha at the bus station.
#
# List of words:
# ['Joe', 'waited', 'for', 'the', 'train', '.', 'The', 'train', 'was', 'late', '.', 'Mary', 'and', 'Samantha', 'took', 'the', 'bus', '.', 'I', 'looked', 'for', 'Mary', 'and', 'Samantha', 'at', 'the', 'bus', 'station', '.']

# %% [markdown]
# Merge the first name and last name as single token in the given sentence
# Input:
# text="Robert Langdon is a famous character in various books and movies"
# Desired Output:
# Robert Langdon
# is
# a
# famous
# character
# in
# various
# books
# and
# movies

# %%
# trong file code.py

# %% [markdown]
# Write a function that takes a text and a vocabulary as its arguments and returns the set of words that appear in the text but not in the vocabulary. Both arguments can be represented as lists of strings.

# %%
def diff(text, vocab):
    return set(text).difference(vocab)


# chỉnh lại cái text và cái vocab theo đề 
text = 'a text and a vocabulary' 
text_lst = text.split()

vocab = 'a vocabulary'
vocab_lst = vocab.split()

diff(text_lst, vocab_lst)
# Out:
# ['a', 'text', 'and', 'a', 'vocabulary']
# ['a', 'vocabulary']
# {'and', 'text'}

# %% [markdown]
# lexicon

# %%
from nltk.corpus import cmudict

def lookup_word(word_s):
    return cmudict.dict().get(word_s)

lookup_word()
